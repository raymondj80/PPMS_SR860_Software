# %%
import socket
import sys
from time import sleep

from RemoteQDInstrument import remoteQDInstrument
from server_params import _HOST, _PORT

# %%
import RemoteQDInstrument

# %%
RemoteQDInstrument
# Out:
# <module 'RemoteQDInstrument' from 'C:\\Users\\Public\\Documents\\PyQD_0\\RemoteQDInstrument.py'>

# %%
rQD = remoteQDInstrument(instrument_type="DYNACOOL",host=_HOST, port=_PORT)

# %%
rQD.connect_socket()
# Out:
# <ipykernel.iostream.OutStream object at 0x00000239426D30D0> connecting to localhost port 5000

# %%
rQD.set_field(field=-10000,rate=200, wait=False, delay = 1)
# Out:
# 'True'

# %%
rQD.field_status(verbose=True)
# Out:
# 'Holding (Driven)'

# %%
rQD.set_temperature(temperature=45)

# %%
rQD.temperature_status(verbose=False)

# %%
rQD.close_socket()
